# %% [markdown]
# # Complainer-User Profile â€” Debug Notebook
#
# Standalone debug notebook. Loads every CSV saved under
# esults/ and re-renders charts using pandas + matplotlib. No database connection required.
#
# **Analyst:** liati Â· **Date:** 2026-04-20 Â· **Analysis:** 2024-06-17 to 2025-06-17 snapshot.
#
# **Question:** What observable, measurable characteristics distinguish users who file complaint-like support tickets (ug or illing) from users who do not?
#
# **Headline answer:** Only one â€” plan = 'free' (28% complaint rate vs 14.7% paid, Ï‡Â² p = 0.034, RR 1.91 [1.06, 3.44]). Role, tenure, and industry do not distinguish. Engagement is not testable at current event-data coverage.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

ROOT = Path.cwd().parent if Path.cwd().name == 'deliverables' else Path.cwd()
RESULTS = ROOT / 'results'
print('Analysis root:', ROOT)
print('Results dir:  ', RESULTS, '(exists:', RESULTS.exists(), ')')

# %% [markdown]
# ## Plan & Hypotheses
#
# The plan.md file in the analysis root captures the hypotheses, decisions, checkpoints, and revisions throughout the analysis. Run the cell below to display it inline; otherwise open it directly from the analysis folder.

# %%
from IPython.display import Markdown, display
display(Markdown((ROOT / 'plan.md').read_text(encoding='utf-8')))

# %% [markdown]
# ## Data QA
#
# Phase report below is pulled from `results/qa/qa-report.md`.

# %%
from IPython.display import Markdown, display
display(Markdown((RESULTS / 'qa' / 'qa-report.md').read_text(encoding='utf-8')))

# %%
df = pd.read_csv(RESULTS / 'qa' / '00_qa-rowcounts.csv')
print('00_qa-rowcounts', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '01_qa-nulls-support-tickets.csv')
print('01_qa-nulls-support-tickets', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '02_qa-nulls-users.csv')
print('02_qa-nulls-users', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '03_qa-nulls-accounts.csv')
print('03_qa-nulls-accounts', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '04_qa-nulls-events.csv')
print('04_qa-nulls-events', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '05_qa-nulls-subs-invoices.csv')
print('05_qa-nulls-subs-invoices', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '06_qa-category-enum.csv')
print('06_qa-category-enum', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '07_qa-role-distribution.csv')
print('07_qa-role-distribution', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '08_qa-plan-distribution.csv')
print('08_qa-plan-distribution', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '09_qa-join-coverage.csv')
print('09_qa-join-coverage', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '10_qa-time-coverage.csv')
print('10_qa-time-coverage', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '11_qa-population-sizes.csv')
print('11_qa-population-sizes', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '12_qa-duplicates.csv')
print('12_qa-duplicates', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '13_qa-status-distribution.csv')
print('13_qa-status-distribution', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'qa' / '14_qa-complainers-by-category.csv')
print('14_qa-complainers-by-category', df.shape)
df.head(20)

# %% [markdown]
# ## EDA
#
# Phase report below is pulled from `results/eda/eda-findings.md`.

# %%
from IPython.display import Markdown, display
display(Markdown((RESULTS / 'eda' / 'eda-findings.md').read_text(encoding='utf-8')))

# %%
df = pd.read_csv(RESULTS / 'eda' / '20_eda-complaint-rate-overall.csv')
print('20_eda-complaint-rate-overall', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '21_eda-complaint-rate-by-plan.csv')
print('21_eda-complaint-rate-by-plan', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '22_eda-complaint-rate-by-role.csv')
print('22_eda-complaint-rate-by-role', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '23_eda-complaint-rate-by-tenure.csv')
print('23_eda-complaint-rate-by-tenure', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '24_eda-category-mix-by-plan.csv')
print('24_eda-category-mix-by-plan', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '25_eda-monthly-complaint-volume.csv')
print('25_eda-monthly-complaint-volume', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '26_eda-events-per-user-distribution.csv')
print('26_eda-events-per-user-distribution', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '26b_eda-events-per-user-histogram.csv')
print('26b_eda-events-per-user-histogram', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '27_eda-pre-complaint-engagement.csv')
print('27_eda-pre-complaint-engagement', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '28_eda-events-per-user-by-plan.csv')
print('28_eda-events-per-user-by-plan', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'eda' / '29_eda-complaint-rate-by-industry.csv')
print('29_eda-complaint-rate-by-industry', df.shape)
df.head(20)

# %% [markdown]
# ## Deep Analysis
#
# Phase report below is pulled from `results/deep-analysis/deep-analysis.md`.

# %%
from IPython.display import Markdown, display
display(Markdown((RESULTS / 'deep-analysis' / 'deep-analysis.md').read_text(encoding='utf-8')))

# %%
df = pd.read_csv(RESULTS / 'deep-analysis' / '40_da-plan-complainer.csv')
print('40_da-plan-complainer', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'deep-analysis' / '41_da-role-complainer.csv')
print('41_da-role-complainer', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'deep-analysis' / '42_da-tenure-complainer.csv')
print('42_da-tenure-complainer', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'deep-analysis' / '43_da-engagement-mann-whitney.csv')
print('43_da-engagement-mann-whitney', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'deep-analysis' / '44_da-engagement-stratified.csv')
print('44_da-engagement-stratified', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'deep-analysis' / '45_da-category-mix.csv')
print('45_da-category-mix', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'deep-analysis' / '46_da-industry-account-level.csv')
print('46_da-industry-account-level', df.shape)
df.head(20)

# %% [markdown]
# ## Synthesis
#
# Phase report below is pulled from `results/synthesis/synthesis.md`.

# %%
from IPython.display import Markdown, display
display(Markdown((RESULTS / 'synthesis' / 'synthesis.md').read_text(encoding='utf-8')))

# %% [markdown]
# ## Validation
#
# Phase report below is pulled from `results/validation/validation.md`.

# %%
from IPython.display import Markdown, display
display(Markdown((RESULTS / 'validation' / 'validation.md').read_text(encoding='utf-8')))

# %%
df = pd.read_csv(RESULTS / 'validation' / '50_val-alt-complaint-defs.csv')
print('50_val-alt-complaint-defs', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'validation' / '51_val-plan-tenure-cross.csv')
print('51_val-plan-tenure-cross', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'validation' / '52_val-mwu-corrected-ranks.csv')
print('52_val-mwu-corrected-ranks', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'validation' / '53_val-mwu-coverage-restricted.csv')
print('53_val-mwu-coverage-restricted', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'validation' / '54_val-temporal-split.csv')
print('54_val-temporal-split', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'validation' / '55_val-watchlist-rules.csv')
print('55_val-watchlist-rules', df.shape)
df.head(20)

# %%
df = pd.read_csv(RESULTS / 'validation' / '56_val-events-coverage.csv')
print('56_val-events-coverage', df.shape)
df.head(20)

# %% [markdown]
# ## Conclusions & recommendations
#
# See deliverables/report.html (full interactive report) and deliverables/summary.pdf (one-page executive summary).
#
# **Survivor summary after validation:**
# - **Confirmed (narrowed):** plan='free' â†’ ~1.9Ã— complaint rate, within 2024-12-17 to 2025-06-17.
# - **Refuted:** role, tenure, industry (underpowered) do not distinguish complainers.
# - **Inconclusive / not testable:** H2 engagement â€” event data covers only ~90 of 365 window days.
# - **Withdrawn:** earlier "disengagement" reframe (built on rank-sum SQL bug + event-coverage artifact).
#
# **Recommended watch-list rule:** plan = 'free' â€” precision 28%, recall 39%, lift 1.56Ã—. Simple, unconfounded, honest.
#
# **Do not deploy:** any rule containing ev_14 = 0 (below-baseline precision) or involving ev_30 = 0 until event-data coverage extends to â‰¥6 months overlapping the complaint window.

# %% [markdown]
# ## How to re-run against the database
#
# This notebook uses the CSVs saved under
# esults/. To re-run any query from scratch, open the matching file in queries/ and execute it via the Supabase MCP, then overwrite the corresponding CSV under
# esults/<phase>/.
#
# All queries in this analysis are deterministic against the frozen 2025-06-17 snapshot.
